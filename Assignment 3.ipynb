# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# ## Numpy
# Q1. How many unique values are there in the &#39;Outcome&#39; column using NumPy?

# %%
outcome_array = df['Outcome'].to_numpy()
np.unique(outcome_array)
# Out:
# array([0, 1], dtype=int64)

# %%
print(f"There are {len(np.unique(df['Outcome']))} unique values in Outcome Column")
# Out:
# There are 2 unique values in Outcome Column

# %% [markdown]
# Q2. Compute the mean and standard deviation of &#39;Glucose&#39; levels using NumPy.

# %%
mean = np.mean(df['Glucose'])
std = np.std(df['Glucose'])

print(f"Mean: {round(mean,2)}\nStandard Deviation: {round(std,2)}")
# Out:
# Mean: 120.89
# Standard Deviation: 31.95

# %% [markdown]
# Q3. Create a NumPy array from the &#39;BMI&#39; column and find the median.

# %%
BMI_array = df['BMI'].to_numpy()
BMI_median = np.median(BMI_array)
print(f"BMI Median: {BMI_median}")
# Out:
# BMI Median: 32.0

# %% [markdown]
# Q4. Using NumPy, count how many patients are there for each unique number of
# pregnancies.

# %%
unique, counts = np.unique(df['Pregnancies'], return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [[  0 111]
#  [  1 135]
#  [  2 103]
#  [  3  75]
#  [  4  68]
#  [  5  57]
#  [  6  50]
#  [  7  45]
#  [  8  38]
#  [  9  28]
#  [ 10  24]
#  [ 11  11]
#  [ 12   9]
#  [ 13  10]
#  [ 14   2]
#  [ 15   1]
#  [ 17   1]]

# %%
unique, counts = np.unique(df['Pregnancies'], return_counts=True)
for u, c in zip(unique,counts):
    print(f"{u}: {c}")
# Out:
# 0: 111
# 1: 135
# 2: 103
# 3: 75
# 4: 68
# 5: 57
# 6: 50
# 7: 45
# 8: 38
# 9: 28
# 10: 24
# 11: 11
# 12: 9
# 13: 10
# 14: 2
# 15: 1
# 17: 1

# %% [markdown]
# Q5. Determine the maximum and minimum insulin level using NumPy.

# %%
insulin_level = df['Insulin'].to_numpy()
min_insulin_level = np.min(insulin_level)
max_insulin_level = np.max(insulin_level)

print(f"Insulin Max Level: {max_insulin_level}\nInsulin Min Level: {min_insulin_level}")
# Out:
# Insulin Max Level: 846
# Insulin Min Level: 0

# %% [markdown]
# Q6. Calculate the variance of Age in the dataset using NumPy.

# %%
age_variance = np.var(df['Age'])
print(f"Variance of Age: {round(age_variance, ndigits=2)}")
# Out:
# Variance of Age: 138.12

# %% [markdown]
# Q7. Filter the array of Glucose to include only values greater than the mean glucose level.

# %%
np.array([x for x in df['Glucose'] if x > np.mean(df['Glucose'])])
# Out:
# array([148, 183, 137, 197, 125, 168, 139, 189, 166, 126, 196, 143, 125,
#        147, 145, 158, 122, 138, 180, 133, 171, 159, 180, 146, 176, 150,
#        187, 146, 133, 141, 146, 139, 126, 129, 131, 137, 136, 123, 134,
#        142, 144, 122, 163, 151, 125, 126, 144, 171, 155, 160, 146, 124,
#        162, 132, 173, 122, 170, 125, 129, 128, 154, 147, 136, 156, 153,
#        188, 152, 163, 151, 131, 148, 134, 179, 129, 143, 130, 141, 194,
#        181, 128, 139, 123, 159, 135, 158, 148, 138, 196, 162, 184, 147,
#        179, 140, 151, 125, 177, 158, 142, 162, 197, 142, 134, 122, 171,
#        181, 179, 164, 139, 146, 184, 122, 165, 124, 129, 193, 155, 191,
#        141, 142, 123, 138, 128, 146, 122, 146, 129, 133, 161, 136, 155,
#        128, 128, 161, 151, 146, 126, 167, 144, 150, 161, 137, 128, 124,
#        155, 182, 194, 129, 124, 152, 157, 122, 179, 180, 165, 152, 178,
#        130, 122, 126, 139, 137, 165, 125, 129, 196, 189, 158, 146, 147,
# ...

# %%
np.fromiter([x for x in df['Glucose'] if x > np.mean(df['Glucose'])],dtype='int64')
# Out:
# array([148, 183, 137, 197, 125, 168, 139, 189, 166, 126, 196, 143, 125,
#        147, 145, 158, 122, 138, 180, 133, 171, 159, 180, 146, 176, 150,
#        187, 146, 133, 141, 146, 139, 126, 129, 131, 137, 136, 123, 134,
#        142, 144, 122, 163, 151, 125, 126, 144, 171, 155, 160, 146, 124,
#        162, 132, 173, 122, 170, 125, 129, 128, 154, 147, 136, 156, 153,
#        188, 152, 163, 151, 131, 148, 134, 179, 129, 143, 130, 141, 194,
#        181, 128, 139, 123, 159, 135, 158, 148, 138, 196, 162, 184, 147,
#        179, 140, 151, 125, 177, 158, 142, 162, 197, 142, 134, 122, 171,
#        181, 179, 164, 139, 146, 184, 122, 165, 124, 129, 193, 155, 191,
#        141, 142, 123, 138, 128, 146, 122, 146, 129, 133, 161, 136, 155,
#        128, 128, 161, 151, 146, 126, 167, 144, 150, 161, 137, 128, 124,
#        155, 182, 194, 129, 124, 152, 157, 122, 179, 180, 165, 152, 178,
#        130, 122, 126, 139, 137, 165, 125, 129, 196, 189, 158, 146, 147,
# ...

# %% [markdown]
# Q8. Using NumPy, create a function to normalize the BloodPressure values (subtract the mean and divide by the standard deviation).

# %%
def normalize(columnname):
    column_name = columnname.to_numpy()
    mean = np.mean(column_name)
    std = np.std(column_name)
    normalized = (column_name - mean)/std
    return normalized

# %%
normalize(df['Glucose'])
# Out:
# array([ 8.48323795e-01, -1.12339636e+00,  1.94372388e+00, -9.98207780e-01,
#         5.04055196e-01, -1.53184856e-01, -1.34247638e+00, -1.84482001e-01,
#         2.38188392e+00,  1.28489452e-01, -3.40967728e-01,  1.47426670e+00,
#         5.66649487e-01,  2.13150675e+00,  1.41167241e+00, -6.53939181e-01,
#        -9.05905652e-02, -4.34859164e-01, -5.60047745e-01, -1.84482001e-01,
#         1.59786597e-01, -6.85236326e-01,  2.35058677e+00, -5.92934199e-02,
#         6.91838068e-01,  1.28489452e-01,  8.17026649e-01, -7.47830617e-01,
#         7.54432359e-01, -1.21887711e-01, -3.72264873e-01,  1.16129525e+00,
#        -1.02950492e+00, -9.04316344e-01,  3.45980161e-02, -5.60047745e-01,
#         5.35352341e-01, -5.91344890e-01, -9.66910634e-01, -3.09670582e-01,
#         1.84983245e+00,  3.78866615e-01, -4.66156309e-01,  1.56815814e+00,
#         1.19259239e+00,  1.84983245e+00,  7.85729504e-01, -1.56155640e+00,
# ...

# %% [markdown]
# Q9. Compute the 25th percentile of DiabetesPedigreeFunction using NumPy.

# %%
np.percentile(df['DiabetesPedigreeFunction'],25)
# Out:
# 0.24375

# %% [markdown]
# ### Pandas
# Q1. Load the dataset and display the first 10 rows.

# %%
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %% [markdown]
# Q2. Show the summary statistics for all numerical columns.

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# Q3. How many missing (zero) values are in the Insulin column?

# %%
zeros_count = len(df[df['Insulin'] == 0])

print(f"Missing (zero) values in the Insulin column are {zeros_count}.")
# Out:
# Missing (zero) values in the Insulin column are 374.

# %%
missing_values = (df['Insulin'] == 0).sum()

print(f"There are {missing_values} missing (zero) values in the Insulin column.")
# Out:
# There are 374 missing (zero) values in the Insulin column.

# %%
df['Insulin'][df['Insulin'] == 0].count()
# Out:
# 374

# %% [markdown]
# Q4. Create a new column BMI_Class categorizing BMI values into Underweight, Normal,
# Overweight, and Obese.

# %% [markdown]
# Below 18.5	Underweight\
# 18.5 – 24.9	Healthy Weight\
# 25.0 – 29.9	Overweight\
# 30.0 and Above Obesity

# %%
df['BMI_Class'] = df['BMI'].apply(lambda x : "Underweight" if x <= 18 else("Healthy Weight" if x <= 24.9 else("Overweight" if x <= 29.9 else "Obesity")))
df[['BMI','BMI_Class']]
# Out:
#       BMI       BMI_Class
# 0    33.6         Obesity
# 1    26.6      Overweight
# 2    23.3  Healthy Weight
# 3    28.1      Overweight
# 4    43.1         Obesity
# ..    ...             ...
# 763  32.9         Obesity
# 764  36.8         Obesity
# 765  26.2      Overweight
# 766  30.1         Obesity
# 767  30.4         Obesity
#
# [768 rows x 2 columns]

# %% [markdown]
# Q5. Group the dataset by Outcome and compute the average age for each group.

# %%
df.groupby('Outcome')['Age'].mean()
# Out:
# Outcome
# 0    31.190000
# 1    37.067164
# Name: Age, dtype: float64

# %% [markdown]
# Q6. Filter the data to include only patients with a Glucose level above 120.

# %%
filtered = df['Glucose'] > 120
df[filtered]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# ..           ...      ...            ...            ...      ...   ...
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome       BMI_Class
# ...

# %% [markdown]
# Q7. Using the `query` method, select rows where Age is greater than 30 and BMI is less than 30.

# %%
df.query('(Age > 30 and BMI < 30)')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 9              8      125             96              0        0   0.0
# 12            10      139             80              0        0  27.1
# 14             5      166             72             19      175  25.8
# ..           ...      ...            ...            ...      ...   ...
# 722            1      149             68             29      127  29.3
# 730            3      130             78             23       79  28.4
# 734            2      105             75              0        0  23.3
# 749            6      162             62              0        0  24.3
# 762            9       89             62              0        0  22.5
#
#      DiabetesPedigreeFunction  Age  Outcome       BMI_Class
# ...

# %% [markdown]
# Q8. Drop rows where any of the values in Glucose, loodPressure, BMI are zeros.

# %%
df1 = df.query('(Glucose != 0 and BloodPressure != 0 and BMI != 0)')
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome       BMI_Class
# ...

# %% [markdown]
# Q9. Reset the index of the dataframe after dropping rows.

# %%
df1.reset_index(inplace=True, drop=True)
df1.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7            2      197             70             45      543  30.5
# 8            4      110             92              0        0  37.6
# 9           10      168             74              0        0  38.0
#
#    DiabetesPedigreeFunction  Age  Outcome       BMI_Class
# 0                     0.627   50        1         Obesity
# 1                     0.351   31        0      Overweight
# ...

# %% [markdown]
# Q10. Save a subset of the dataset with columns Age, Glucose, Outcome to a new CSV file.

# %%
df2 = df1[['Age', 'Glucose', 'Outcome']]
df2.to_csv("df1.csv",index = False)

# %% [markdown]
# ### Matplotlib Questions
# Q1. Plot a histogram of Age.

# %%
fig, ax = plt.subplots(figsize=(6,4))
ax.hist(df['Age'], bins=20, edgecolor='white')
ax.set_xlabel('Age')
ax.set_title("Distribution of Age")
plt.show()

# %% [markdown]
# Q2. Create a scatter plot showing Glucose versus Insulin levels.

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.scatter(df['Glucose'], df['Insulin'], alpha=0.7)
ax.set_title("Scatter Plot of Glucose vs Insulin Levels")
ax.set_xlabel("Glucose")
ax.set_ylabel("Insulin")
plt.show()

# %% [markdown]
# Q3. Draw a bar chart comparing the mean BMI across Outcome.

# %%
d = df.groupby(['Outcome'])['Age'].mean()
fig, ax = plt.subplots(figsize=(6,4))
p = ax.bar(d.index,d.values,width = .9,color='skyblue', edgecolor="black")
ax.set_title('Mean BMI Across Outcome')
ax.set_xlabel('Outcome')
ax.set_ylabel('Mean BMI')
ax.set_xticks((0,1))
ax.bar_label(p)

plt.show()

# %% [markdown]
# Q4. Plot a line graph of BloodPressure sorted by Age.

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(df['Age'].sort_values(),df['BloodPressure'])
ax.set_title("Blood Pressure vs Age")
ax.set_xlabel("Age")
ax.set_ylabel("Blood Pressure")
plt.show()

# %% [markdown]
# Q5. Display a box plot of BMI grouped by Outcome.

# %%
bmi = df.groupby("Outcome")["BMI"].apply(list)

fig, ax = plt.subplots(figsize=(8,4))
ax.boxplot(bmi)
plt.title("Box plot of 'BMI' grouped by 'Outcome'")
plt.xlabel("Outcome")
plt.ylabel("BMI")
plt.show()

# %% [markdown]
# Q6. Create a pie chart showing the proportion of diabetes outcomes (0's and 1's).

# %%
x = df['Outcome'].value_counts()
label = df['Outcome'].value_counts().index

fig, ax = plt.subplots(figsize=(8,4))

ax.pie(x, labels=label,autopct='%1.1f%%', startangle=140)
ax.set_title('Proportion of Diabetes Outcomes')
ax.axis('equal') 
plt.show()

# %% [markdown]
# Q7. Plot a stacked bar chart of Pregnancies categorized by Outcome.

# %%
pregnancies = df.groupby(['Pregnancies', 'Outcome']).size().unstack()

pregnancies.plot(kind='bar', stacked=True, figsize=(8, 4))
plt.title("Stacked bar chart of 'Pregnancies' categorized by 'Outcome'")
plt.xlabel('Pregnancies')
plt.ylabel('Outcome')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 4))

bottom = None
for col in pregnancies.columns:
    ax.bar(x=pregnancies.index, height=pregnancies[col], bottom=bottom, label=col)
    if bottom is None:
        bottom = pregnancies[col].values
    else:
        bottom += pregnancies[col].values

ax.set_title('Stacked Bar Chart of Pregnancies Categorized by Outcome')
ax.set_xlabel('Pregnancies')
ax.set_ylabel('Count')
ax.set_xticks(pregnancies.index)

plt.legend(title='Outcome', loc='upper right')
plt.show()

# %% [markdown]
# Q8. Create subplots showing histograms for Glucose and BloodPressure.

# %%
fig, axs = plt.subplots(nrows=1,ncols=2, figsize=(12,4))

axs[0].hist(df['Glucose'], bins=20,edgecolor='white')
axs[0].set_title("Glucose Distribution")
axs[0].set_xlabel("Glucose Levels")

axs[1].hist(df['BloodPressure'], bins=20,edgecolor='white')
axs[1].set_title("Blood Pressure Distribution")
axs[1].set_xlabel("Blood Pressure Levels")

plt.show()

# %% [markdown]
# Q9. Generate a heat map of the correlation matrix of the dataset.

# %%
corr = df.corr(numeric_only=True) 

sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation matrix')
plt.show()
